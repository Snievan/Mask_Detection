# %% [markdown]
# ### Import Libraries

# %%
import os
import random
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from livelossplot import PlotLossesKerasTF
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# ### Samlpe Raw Data

# %%
train_face_dir = './data/face'
train_mask_dir = './data/mask'
face_fnames = os.listdir(train_face_dir)
mask_fnames = os.listdir(train_mask_dir)

print("Total face images:", len(os.listdir(train_face_dir)))
print("Total mask images:", len(os.listdir(train_mask_dir)))
# Out:
# Total face images: 2203
# Total mask images: 2203

# %%
nrows , ncols = 4,4
pic_index = 0 
random.shuffle(face_fnames)
random.shuffle(mask_fnames)

# %%
# Run this cell, each time show 8 positive and 8 negative samples
fig = plt.gcf()
fig.set_size_inches(ncols * 3, nrows *3)
pic_index+=8

next_cat_pix = [os.path.join(train_face_dir,f) for f in face_fnames[pic_index-8:pic_index]]
next_dog_pix = [os.path.join(train_mask_dir,f) for f in mask_fnames[pic_index-8:pic_index]]

for i,img_path in enumerate(next_cat_pix +  next_dog_pix):
    sp = plt.subplot(ncols,nrows,i+1)
    sp.axis("Off")
    img = mpimg.imread(img_path)
    plt.imshow(img)
plt.show()

# %% [markdown]
# ### Generate Training and Validation Batches
# - Split train and validation as 0.8 to 0.2

# %%
train_data_dir = './data'
batch_size = 32
img_size = (150,150)
nb_epochs = 20

train_datagen = ImageDataGenerator(rescale = 1/255.,
                                  rotation_range=20,
                                  shear_range=0.2,
                                  horizontal_flip=True,
                                  validation_split = 0.2)

train_generator = train_datagen.flow_from_directory(train_data_dir,
                                                   target_size = img_size,
                                                   batch_size = batch_size,
                                                   class_mode = "binary",
                                                   subset = 'training')

validation_generator = train_datagen.flow_from_directory(train_data_dir,
                                                   target_size = img_size,
                                                   batch_size = batch_size,
                                                   class_mode = "binary",
                                                       subset = "validation")
# Out:
# Found 3526 images belonging to 2 classes.
# Found 880 images belonging to 2 classes.

# %% [markdown]
# ### Create CNN Model
# - Using existing model with pretrained weight
# - Resize images to 150x150

# %%
from tensorflow.keras.applications import MobileNetV2
# use pre-trained model
pre_trained_model = MobileNetV2(input_shape=(128,128,3),
                      include_top=False)
for layer in pre_trained_model.layers:
    layer.trainable = False

model = tf.keras.Sequential([
    pre_trained_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation = 'relu'),
    layers.Dropout(0.2),
    layers.Dense(1, activation = 'sigmoid') 
])

model.compile(optimizer = RMSprop(lr= 0.001),
             loss = "binary_crossentropy",
             metrics = ["accuracy"])

# %% [markdown]
# ### Train, Save and Evaluate Model

# %%
# %%time

epochs = 15 
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              patience=2, min_lr=0.00001, mode='auto')
checkpoint = ModelCheckpoint("./models/mask_detect_model.h5", monitor='val_accuracy',
                             save_best_only=True, mode='max', verbose=1)
callbacks = [PlotLossesKerasTF(), checkpoint, reduce_lr]

history = model.fit(
    train_generator,
    steps_per_epoch = train_generator.samples // batch_size,
    validation_data = validation_generator, 
    validation_steps = validation_generator.samples // batch_size,
    callbacks = callbacks,
    epochs = epochs)
# Out:
# accuracy
# 	training         	 (min:    0.970, max:    0.998, cur:    0.998)
# 	validation       	 (min:    0.988, max:    0.995, cur:    0.995)
# Loss
# 	training         	 (min:    0.006, max:    0.103, cur:    0.007)
# 	validation       	 (min:    0.026, max:    0.045, cur:    0.030)
#
# Epoch 00015: val_accuracy did not improve from 0.99537
# 110/110 [==============================] - 33s 298ms/step - loss: 0.0075 - accuracy: 0.9977 - val_loss: 0.0300 - val_accuracy: 0.9954
# Wall time: 7min 43s

# %% [markdown]
# ###  Model Test
# 1. Load trained model
# 2. OpenCV to Face Detection
# 3. Augment image with predictions

# %%
import tensorflow as tf
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img_resize = (128,128)
model = tf.keras.models.load_model('./models/mask_detect_model.h5')

def predict(face_img):
    """Use model to classify mask """
    # face_img = cv2.cvtColor(face_img, cv2.COLOR_BGR2RGB)
    face_img = cv2.resize(face_img, img_resize)
    face_img = face_img / 255.
    face_img = np.expand_dims(face_img,0)
    pred = model.predict(face_img)[0][0]
    return pred

img = mpimg.imread('./images/b1.jpg')
plt.title("Raw image")
plt.imshow(img)

# %%
facec = cv2.CascadeClassifier('./models/haarcascade_frontalface_default.xml')
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
faces = facec.detectMultiScale(gray, 1.3, 5)

ax = plt.gca()
for (x, y, w, h) in faces:
    face_img = img[y:y+h,x:x+w]
    pred = predict(face_img)
    if pred>= 0.5:
        ax.add_patch(plt.Rectangle( (x,y), width = w, height = h, edgecolor = "yellow", fill = False))
        plt.text(x,y,'Mask %.1f%%' % (pred*100),color = "yellow")
    elif pred<0.5:
        ax.add_patch(plt.Rectangle( (x,y), width = w, height = h, edgecolor = "red", fill = False))
        plt.text(x,y,'Face %.1f%%' % (pred*100), color = "red")
plt.title("Augmented image")
plt.imshow(img)
